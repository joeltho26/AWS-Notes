# %% [markdown]
# 1. [DNS](#dns)
# 2. [DNS hierarchical naming structure](#dns-hierarchical-naming-structure)
# 3. [What is DNS Name Space](#what-is-dns-name-space)
# 4. [DNS terminologies](#dns-terminologies)
# 5. [How DNS work](#how-dns-work)

# %% [markdown]
# #### DNS:
# - Domain Name System
# - translates human friendly host names to machine IP addresses
# - eg: 172.217.18.36 => www.google.com
# - DNS is backbone of internet

# %% [markdown]
# #### DNS hierarchical naming structure:
# - . (root)
# - .com. (top level domain)
# - google.com. (second level domain)
# - www.google.com. (sub domain)
# - api.www.google.com. (fully qualified domain name - FQDN)
# - http:// (protocol)
# - http://api.www.amazon.com. (URL)

# %% [markdown]
# #### What is DNS Name Space:
#
# - DNS Name Space is the set of all domain names that are registered in the DNS. These domain names are organized into a tree-like structure, with the top of the tree being the root domain. Below the root domain, there are a number of top-level domains, such as .com, . net, and . org

# %% [markdown]
# #### DNS terminologies:
# - Domain Registrar:
#     - Amazon Route 53, GoDaddy, etc
# - DNS Records:
#     - A, AAAA, CNAME, NS, etc
# - Zone file:
#     - contains DNS records
# - Name Server:
#     - resolves DNS queries
# - Top Level Domain:
#     - .org, .gov, .com, etc
# - Second Level Domain:
#     - amazon.com, us.gov, etc

# %% [markdown]
# #### How DNS work:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/DNS.jpeg')
new_image = img.resize((700, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=700x350>
