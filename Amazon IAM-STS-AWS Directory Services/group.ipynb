# %% [markdown]
# ## IAM Group:
# - Groups a set of users to have similar permissions

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('IAM.jpeg')
new_image = img.resize((500, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x150>
